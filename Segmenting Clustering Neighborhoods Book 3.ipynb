# %% [markdown]
# # Scope of this Notebook
#
# Explore and cluster the neighborhoods in Toronto. You can decide to work with only boroughs that contain the word Toronto and then replicate the same analysis we did to the New York City data. It is up to you.
#
# Just make sure:
# 1. to add enough Markdown cells to explain what you decided to do and to report any observations you make.
# 2. to generate maps to visualize your neighborhoods and how they cluster together.
#
# Once you are happy with your analysis, submit a link to the new Notebook on your Github repository. __(3 marks)__

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# geopy                     1.17.0                     py_0    conda-forge
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# folium                    0.5.0                      py_0    conda-forge

# %% [markdown]
# # Map displaying Toronto's Neighborhoods based on Postal Code

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# ### Let's Explore Ryerson, Garden District Neighborhood in the Downtown Borough.

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Latitude and longitude values of Ryerson, Garden District are 43.6571618, -79.37893709999999.

# %%
# The code was removed by Watson Studio for sharing.

# %%
venues = results['response']['groups'][0]['items']
nearby_venues = json_normalize(venues) # flatten JSON
# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
try:
    nearby_venues =nearby_venues.loc[:, filtered_columns]
    # filter the category for each row
    nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)
    # clean columns
    nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
except:
    nearby_venues=pd.DataFrame()
nearby_venues.columns=["Venue Name","Venue Category","Latitude","Longitude"]
print('{} Venues were returned for Neighborhood - {} , Borough - {} by Foursquare.'.format(nearby_venues.shape[0], downtown_toronto_data.Neighborhood[0], downtown_toronto_data.Borough[0]))
# Out:
# 100 Venues were returned for Neighborhood - Ryerson, Garden District , Borough - Downtown Toronto by Foursquare.

# %% [markdown]
# ### Printing the Top 10 Venue Categories in this Neighborhood

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#                      Venue Name
# Venue Category
# Coffee Shop                  10
# Hotel                         5
# Restaurant                    3
# Diner                         3
# Gastropub                     3
# Park                          3
# Concert Hall                  3
# Café                          3
# Japanese Restaurant           3
# Theater                       3

# %% [markdown]
# ### Printing the Details about the Venues related to Top 10 Categories in this Neighborhood

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#                                      Venue Name       Venue Category  \
# 0                                 Page One Cafe                 Café
# 1                            Ed Mirvish Theatre              Theater
# 2                        Kinka Izakaya Original  Japanese Restaurant
# 3              Elgin And Winter Garden Theatres              Theater
# 4              The Grand Hotel & Suites Toronto                Hotel
# 5             The Queen and Beaver Public House            Gastropub
# 6                             GEORGE Restaurant           Restaurant
# 7                                Jimmy's Coffee          Coffee Shop
# 8                             Fahrenheit Coffee          Coffee Shop
# 9                                 Dineen Coffee                 Café
# 10                      The George Street Diner                Diner
# 11                                   Beerbistro            Gastropub
# 12  Four Seasons Centre for the Performing Arts         Concert Hall
# 13                                        Canoe           Restaurant
# 14                               NEO COFFEE BAR          Coffee Shop
# 15                               Rooster Coffee          Coffee Shop
# 16                          House on Parliament            Gastropub
# 17                           Shangri-La Toronto                Hotel
# 18                             Roy Thomson Hall         Concert Hall
# 19                               Kingyo Toronto  Japanese Restaurant
# 20                    Princess Of Wales Theatre              Theater
# 21                        Pilot Coffee Roasters          Coffee Shop
# 22                      The Fairmont Royal York                Hotel
# 23                                 Queen's Park                 Park
# 24                     The Ritz-Carlton Toronto                Hotel
# 25                                  Cranberries                Diner
# 26             Delta Hotels by Marriott Toronto                Hotel
# 27                                         Arvo          Coffee Shop
# 28                                Tandem Coffee          Coffee Shop
# 29                              Roundhouse Park                 Park
# 30                          Avenue Open Kitchen                Diner
# 31                               Little Pebbles          Coffee Shop
# 32                          Riverdale Park West                 Park
# 33                            The Moonbean Cafe                 Café
# 34                                 Koerner Hall         Concert Hall
# 35                              Balzac's Coffee          Coffee Shop
# 36                                         Miku  Japanese Restaurant
# 37                               Impact Kitchen           Restaurant
# 38                         The Alternative Cafe          Coffee Shop
#
#      Latitude  Longitude
# 0   43.657772 -79.376073
# 1   43.655102 -79.379768
# 2   43.660596 -79.378891
# 3   43.653394 -79.378507
# 4   43.656449 -79.374110
# 5   43.657472 -79.383524
# 6   43.653346 -79.374445
# 7   43.658421 -79.385613
# 8   43.652384 -79.372719
# 9   43.650497 -79.378765
# 10  43.652803 -79.371563
# 11  43.649419 -79.377237
# 12  43.650609 -79.386280
# 13  43.647452 -79.381320
# 14  43.650702 -79.369259
# 15  43.651900 -79.365609
# 16  43.663646 -79.367854
# 17  43.649129 -79.386557
# 18  43.646589 -79.385979
# 19  43.665895 -79.368415
# 20  43.646543 -79.389100
# 21  43.645018 -79.380415
# 22  43.645449 -79.381508
# 23  43.663946 -79.392180
# 24  43.645330 -79.387089
# 25  43.667843 -79.369407
# 26  43.642882 -79.383949
# 27  43.649963 -79.361442
# 28  43.653559 -79.361809
# 29  43.641745 -79.384279
# 30  43.647273 -79.396320
# 31  43.654883 -79.400264
# 32  43.666048 -79.360941
# 33  43.654147 -79.400182
# 34  43.667983 -79.395962
# 35  43.649797 -79.359142
# 36  43.641255 -79.377371
# 37  43.656369 -79.356980
# 38  43.647852 -79.397014

# %% [markdown]
# ### Map displaying these 100 venues

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# The geograpical coordinate of Downtown, Toronto are 43.655115, -79.380219.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Let's Cluster these 100 Venues into 4 groups and diplay them in a map in different colors

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Hope you enjoyed this analysis
